# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
contrails1 = pd.read_csv('Extracted Data/Ice Data/contrails 1.csv')
# contrails1.head()
contrails1.set_index('Timesteps', inplace=True)

# %%
contrails2 = pd.read_csv('Extracted Data/Ice Data/contrails 2.csv')
# contrails2.head()
contrails2.set_index('Timesteps', inplace=True)

# %%
contrails3 = pd.read_csv('Extracted Data/Ice Data/contrails 3.csv')
# contrails3.head()
contrails3.set_index('Timesteps', inplace=True)

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, figsize=(10,20))
ax1.plot(contrails1.Percentage)
ax1.set_title('Data 1')
ax2.plot(contrails2.Percentage)
ax2.set_title('Data 2')
ax3.plot(contrails3.Percentage)
ax3.set_title('Data 3')

fig.tight_layout()
