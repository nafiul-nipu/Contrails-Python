# %%
import pandas as pd
import numpy as np
from os import listdir
import json
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
"column is the attribute name for binning"
column = 'd'
"ranges store all the contrails data range"
ranges = {}

# %%
"""getting the minimum and maximum range for the binning"""
folders = [f for f in listdir("data/onlyIce/")]
# folders = ['newData']
for folder in folders:
    ranges[folder] = list()
    onlyfiles = [f for f in listdir("data/onlyIce/{}".format(folder)) ]
#     onlyfiles = ["0.07.csv", "0.08.csv"]
    path = "data/onlyIce/{}/{}".format(folder, onlyfiles[0])
    timeStepData = pd.read_csv(path)
    iceData = timeStepData[timeStepData.iceLabel == 1]        
    columnData = iceData[column]
    ranges[folder].append(columnData.min())
    ranges[folder].append(columnData.max())
#     print(min_val, max_val)
    for i in range(1, len(onlyfiles)):
        path = "data/onlyIce/{}/{}".format(folder, onlyfiles[i])
        timeStepData = pd.read_csv(path)
        iceData = timeStepData[timeStepData.iceLabel == 1]        
        columnData = iceData[column]
        if columnData.min() < ranges[folder][0] :
            ranges[folder][0] = columnData.min()
        if columnData.max() > ranges[folder][1] : 
            ranges[folder][1] = columnData.max()
        
print(ranges)
# Out:
# {'contrails1': [1e-05, 1.4242e-05], 'contrails2': [1e-05, 1.512e-05], 'contrails3': [1e-05, 1.4016e-05], 'newData': [2.0054e-08, 3.4125e-06]}

# %%
folders = [f for f in listdir("data/onlyIce/")]
folders = ['newData']
fig, axs = plt.subplots(ncols=len(folders))
for folder in folders:
    ranges[folder] = list()
    onlyfiles = [f for f in listdir("data/onlyIce/{}".format(folder)) ]
    for i in range(len(onlyfiles)):
        path = "data/onlyIce/{}/{}".format(folder, onlyfiles[i])
        timeStepData = pd.read_csv(path)
        iceData = timeStepData[timeStepData.iceLabel == 1]        
        columnData = iceData[column]
        columnData = pd.to_numeric(columnData)
        print(columnData)
        sns.kdeplot(columnData, diag_kws={"hue": None, "color": ".2"})
# Out:
# 0        6.109600e-08
# 1        6.109600e-08
# 2        6.109600e-08
# 3        6.109600e-08
# 4        6.109600e-08
#              ...
# 13257    2.236700e-06
# 13258    4.619500e-07
# 13259    1.393100e-06
# 13260    2.549600e-07
# 13261    1.361200e-06
# Name: d, Length: 13262, dtype: float64
# C:\Users\evladmin\Anaconda3\envs\server-png\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_79152/2253949808.py in <module>
#      12         columnData = pd.to_numeric(columnData)
#      13         print(columnData)
# ---> 14         sns.kdeplot(columnData, diag_kws={"hue": None, "color": ".2"})
#
# ~\Anaconda3\envs\server-png\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
# ...

# %%
folders = ['contrails2']
fig, axs = plt.subplots(ncols=len(folders))
for folder in folders:
    ranges[folder] = list()
    onlyfiles = [f for f in listdir("data/{}".format(folder)) ]
    for i in range(len(onlyfiles)):
        path = "data/{}/{}".format(folder, onlyfiles[i])
        timeStepData = pd.read_csv(path)
        iceData = timeStepData[timeStepData.iceLabel == 1]        
        columnData = iceData[column]
        sns.kdeplot(columnData)

# %%
folders = ['contrails3']
fig, axs = plt.subplots(ncols=len(folders))
for folder in folders:
    ranges[folder] = list()
    onlyfiles = [f for f in listdir("data/{}".format(folder)) ]
    for i in range(len(onlyfiles)):
        path = "data/{}/{}".format(folder, onlyfiles[i])
        timeStepData = pd.read_csv(path)
        iceData = timeStepData[timeStepData.iceLabel == 1]        
        columnData = iceData[column]
        sns.kdeplot(columnData)
